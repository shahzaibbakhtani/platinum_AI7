# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\asifb\OneDrive\Desktop\Python language\Jupyter Notebook\Kaggle\School Kaggle.csv", low_memory = False)

# %%
df.set_index("student_ID", inplace = True)

# %%
df.shape
# Out:
# (200994, 10)

# %%
df.head(3)
# Out:
#            schoolyear gradeLevel classPeriod classType        schoolName  \
# student_ID
# 0HRJHI993   2024-2025          7           1       ELE  West Junior High
# CKN322II4   2024-2025          7           1       ELE  West Junior High
# V523OZUH8   2024-2025          7           1       ELE  West Junior High
#
#             gradePercentage avid sped migrant ell
# student_ID
# 0HRJHI993            2000.0    Y    N       N   N
# CKN322II4            2000.0    N    N       N   N
# V523OZUH8            1950.0    N    N       N   N

# %%
df.sample(5)                    # give you random rows
# Out:
#            schoolyear gradeLevel classPeriod classType  \
# student_ID
# 39N1DUY9F   2023-2024          4           5       ENG
# SL42Y8QT8   2022-2023          1           3       MUS
# L278D1IQB   2021-2022          8           0        MS
# 37JYP04TZ   2018-2019          6           1       MUS
# MZJYF6219   2024-2025          1           9       SOC
#
#                                   schoolName  gradePercentage avid sped  \
# student_ID
# 39N1DUY9F   Sunny Hillside Elementary School             92.9    Y    N
# SL42Y8QT8             Gale Elementary School            100.0    Y    N
# L278D1IQB                  North Junior High            100.0    N    N
# 37JYP04TZ                  North Junior High             85.7    N    N
# MZJYF6219   Sunny Hillside Elementary School            100.0    Y    Y
#
#            migrant ell
# student_ID
# 39N1DUY9F        N   N
# SL42Y8QT8        N   N
# L278D1IQB        N   N
# 37JYP04TZ        N   N
# MZJYF6219        N   N

# %%
df.isnull().sum()    # count gives you total number of rows for each column
# Out:
# schoolyear         0
# gradeLevel         0
# classPeriod        0
# classType          0
# schoolName         0
# gradePercentage    0
# avid               0
# sped               0
# migrant            0
# ell                0
# dtype: int64

# %%
df.describe(include = "all")
# Out:
#        schoolyear gradeLevel classPeriod classType                schoolName  \
# count      200994     200994      200994    200994                    200994
# unique          6         10          30        10                        19
# top     2024-2025          8           5       ENG  Allfeather Middle School
# freq        54402      42397       29291     44813                     35640
# mean          NaN        NaN         NaN       NaN                       NaN
# std           NaN        NaN         NaN       NaN                       NaN
# min           NaN        NaN         NaN       NaN                       NaN
# 25%           NaN        NaN         NaN       NaN                       NaN
# 50%           NaN        NaN         NaN       NaN                       NaN
# 75%           NaN        NaN         NaN       NaN                       NaN
# max           NaN        NaN         NaN       NaN                       NaN
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(52721)

# %%
df.corr(numeric_only = True)
# Out:
#                  gradePercentage
# gradePercentage              1.0

# %%
df = pd.read_csv(r"C:\Users\asifb\OneDrive\Desktop\Python language\Jupyter Notebook\Kaggle\Hosuing Kaggle.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  str
# dtypes: float64(4), int64(5), str(1)
# memory usage: 1.6 MB

# %%
# Fix dtype
# df["median_house_value"] = pd.to_numeric(df["median_house_value"], errors="coerce")

# %%
df.drop(columns = ["ocean_proximity"], inplace = True)

# %%
df.corr()["median_house_value"]
# Out:
# longitude            -0.045967
# latitude             -0.144160
# housing_median_age    0.105623
# total_rooms           0.134153
# total_bedrooms        0.049686
# population           -0.024650
# households            0.065843
# median_income         0.688075
# median_house_value    1.000000
# Name: median_house_value, dtype: float64

# %% [markdown]
# ### EDA

# %%
df = pd.read_csv(r"C:\Users\asifb\OneDrive\Desktop\Python language\Jupyter Notebook\Kaggle\Titanic-Dataset.csv")

# %%
df.set_index("PassengerId", inplace = True)

# %%
df.head(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["Fare"], df["Survived"])
plt.xlabel("Fare Price")
plt.show()

# %% [markdown]
# ### Univarriate

# %%
df[df["Survived"] == 1].shape[0]
# Out:
# 342

# %%
df[df["Survived"] == 0].shape[0]
# Out:
# 549

# %%
df["Survived"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Survived'>

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df["Pclass"].value_counts().plot(kind = "pie", autopct = "%.2f")
# Out:
# <Axes: >

# %%
plt.hist(df["Age"] , bins = 5)          # to find how many people in each age bracket were in titanic 
plt.show()

# %% [markdown]
# ## Bivariate
