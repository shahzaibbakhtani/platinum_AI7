# %% [markdown]
# # Conditional Expressions

# %%
a = int(input("Enter your age :"))
if(a>=18):
        print("You are above the required age")

elif(a<0):
    print("Bakchodi nahi kar")

elif(a==0):
    print("You are entering zero")
        
else:
    print("You are below the required the age")
# Out:
# Enter your age : -19
# Bakchodi nahi kar

# %%
n = int(input("Enter your marks:"))

if(n>75):
    print("Your Grade is A")
    
elif(n<75):
    print("Your Grade is B")

elif(n<60):
    print("Your grade is C")

else:
    print("You are Fail")
# Out:
# Enter your marks: 55
# Your Grade is B

# %%
n = int(input("Enter your marks: "))

if n >= 75:
    print("Your Grade is A")
elif n >= 60:
    print("Your Grade is B")
elif n >= 40:
    print("Your Grade is C")
else:
    print("You are Fail")
# Out:
# Enter your marks:  55
# Your Grade is C

# %%
age = int(input("Enter your age:"))

if age>18:
    print("yes")
else:
    print("No")
# Out:
# Enter your age: 17
# No

# %%
marks = 85
age = 20

if marks > 75:
    print("Grade A")

if age >= 18:
    print("You are an adult")
# Out:
# Grade A
# You are an adult

# %%
marks = int(input("Enter your marks:"))
age = int(input("Enter your age:"))

if marks >= 75:
          print("A Grade")
elif marks >= 60:
            print("B Grade")
    
else :
    print("Fail")

if age > 22:
    print("High School")
else:
    print("Primiary School")

print("Congratulations and best of luck")
# Out:
# Enter your marks: 76
# Enter your age: 15
# A Grade
# Primiary School
# Congratulations and best of luck

# %%
a = int(input("Enter number a :"))
b = int(input("enter number b:"))
c = int(input("enter number c:"))

if (a>b and a>c):
        print("A is the greatest number:" ,a )

if (b>a and b>c):
        print("B is the greatest number:", b)

if (c>a and c>a):
        print("C is the greatest number:" ,c )
# Out:
# Enter number a : 22
# enter number b: 21
# enter number c: 26
# C is the greatest number: 26

# %% [markdown]
# ## Percentage

# %%
# total should be more than 40% and individual subject marks should be atleast 33 in each 

marks1 = int(input("Enter your  Englis marks:"))
marks2 = int(input("Enter your  Urdu marks:"))
marks3 = int(input("Enter your  Maths marks:"))

total_percentage = (marks1 + marks2 + marks3)/300*100

if total_percentage >= 40 and marks1 >= 33 and marks2 >= 33 and marks3 >= 33:
    print("You are passed and your percentage is:" ,total_percentage)
else:
    print("You are failed, better luck next time and your percentage is :" , total_percentage)
# Out:
# Enter your  Englis marks: 33
# Enter your  Urdu marks: 33
# Enter your  Maths marks: 76
# You are passed and your percentage is: 47.333333333333336

# %%
C1 = "buy now"
C2 = "great sale"
C3 = "free"

comment = input("Enter your comment:")

if C1 in comment or C2 in comment or C3 in comment:
    print("This is a spam be safe")
else:
    print("This is not a spam enjoy surfing")
# Out:
# Enter your comment: this is free and good
# This is a spam be safe

# %%
username = input("Enter your Username:")
if len(username)<=10:
    print("All is well")

else:
    print("Re Enter the passcode")
# Out:
# Enter your Username: 1111111111111111111111
# Re Enter the passcode

# %%
list1 =("Hi","Bye","Good","Bad")

letters = input("Enter your words")

if letters in list1:
    print("Yes, this word is in list")

else:
    print("No, this word is not in the list")
# Out:
# Enter your words Good
# Yes, this word is in list

# %%
post = input("Enter your post:")

if "Shahzaib".lower() in post.lower():
    print("This post is about Shahzaib")
# Out:
# Enter your post: SHAHzaIb is working on python
# This post is about Shahzaib
