# %%
import pandas as pd

# %%
data = {
    "Name": [
        "Liam", "Sophia", "Noah", "Emma", "Oliver", 
        "Ava", "Ethan", "Isabella", "Lucas", "Mia"
    ],
    "Salary": [
        95000, 72000, 105000, 88000, 62000, 
        115000, 54000, 91000, 78000, 83000
    ],
    "Position": [
        "Software Engineer", "Data Scientist", "Project Manager", "UX Designer", "Intern",
        "CTO", "Marketing Associate", "DevOps Engineer", "Sales Lead", "Product Owner"
    ]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#        Name  Salary             Position
# 0      Liam   95000    Software Engineer
# 1    Sophia   72000       Data Scientist
# 2      Noah  105000      Project Manager
# 3      Emma   88000          UX Designer
# 4    Oliver   62000               Intern
# 5       Ava  115000                  CTO
# 6     Ethan   54000  Marketing Associate
# 7  Isabella   91000      DevOps Engineer
# 8     Lucas   78000           Sales Lead
# 9       Mia   83000        Product Owner

# %%
df[df["Salary"] > 100000]
# Out:
#    Name  Salary         Position
# 2  Noah  105000  Project Manager
# 5   Ava  115000              CTO

# %%
df["Name"][0:4]
# Out:
# 0      Liam
# 1    Sophia
# 2      Noah
# 3      Emma
# Name: Name, dtype: str

# %%
df.rename(columns = {"Position" : "Post"} , inplace = True )
df
# Out:
#        Name  Salary                 Post
# 0      Liam   95000    Software Engineer
# 1    Sophia   72000       Data Scientist
# 2      Noah  105000      Project Manager
# 3      Emma   88000          UX Designer
# 4    Oliver   62000               Intern
# 5       Ava  115000                  CTO
# 6     Ethan   54000  Marketing Associate
# 7  Isabella   91000      DevOps Engineer
# 8     Lucas   78000           Sales Lead
# 9       Mia   83000        Product Owner

# %%
df.drop(df.columns[0] ,axis = 1,  inplace = True)
df
# Out:
#    Salary                 Post
# 0   95000    Software Engineer
# 1   72000       Data Scientist
# 2  105000      Project Manager
# 3   88000          UX Designer
# 4   62000               Intern
# 5  115000                  CTO
# 6   54000  Marketing Associate
# 7   91000      DevOps Engineer
# 8   78000           Sales Lead
# 9   83000        Product Owner

# %%
df["Name"] = ["Liam", "Sophia", "Noah", "Emma", "Oliver", 
        "Ava", "Ethan", "Isabella", "Lucas", "Mia"]
df
# Out:
#    Salary                 Post      Name
# 0   95000    Software Engineer      Liam
# 1   72000       Data Scientist    Sophia
# 2  105000      Project Manager      Noah
# 3   88000          UX Designer      Emma
# 4   62000               Intern    Oliver
# 5  115000                  CTO       Ava
# 6   54000  Marketing Associate     Ethan
# 7   91000      DevOps Engineer  Isabella
# 8   78000           Sales Lead     Lucas
# 9   83000        Product Owner       Mia

# %%
df["Bonus"] = df["Salary"] * 0.25
df["Total"] = df["Salary"] + df["Bonus"]
df
# Out:
#    Salary                 Post      Name    Bonus     Total
# 0   95000    Software Engineer      Liam  23750.0  118750.0
# 1   72000       Data Scientist    Sophia  18000.0   90000.0
# 2  105000      Project Manager      Noah  26250.0  131250.0
# 3   88000          UX Designer      Emma  22000.0  110000.0
# 4   62000               Intern    Oliver  15500.0   77500.0
# 5  115000                  CTO       Ava  28750.0  143750.0
# 6   54000  Marketing Associate     Ethan  13500.0   67500.0
# 7   91000      DevOps Engineer  Isabella  22750.0  113750.0
# 8   78000           Sales Lead     Lucas  19500.0   97500.0
# 9   83000        Product Owner       Mia  20750.0  103750.0

# %%
df[df["Salary"] > 95000]
# Out:
#    Salary             Post  Name    Bonus     Total
# 2  105000  Project Manager  Noah  26250.0  131250.0
# 5  115000              CTO   Ava  28750.0  143750.0

# %%
df.columns
# Out:
# Index(['Salary', 'Post', 'Name', 'Bonus', 'Total'], dtype='str')

# %%
df.loc[8 , "Salary"] = 545454
df
# Out:
#    Salary                 Post      Name    Bonus     Total
# 0   95000    Software Engineer      Liam  23750.0  118750.0
# 1   72000       Data Scientist    Sophia  18000.0   90000.0
# 2  105000      Project Manager      Noah  26250.0  131250.0
# 3   88000          UX Designer      Emma  22000.0  110000.0
# 4   62000               Intern    Oliver  15500.0   77500.0
# 5  115000                  CTO       Ava  28750.0  143750.0
# 6   54000  Marketing Associate     Ethan  13500.0   67500.0
# 7   91000      DevOps Engineer  Isabella  22750.0  113750.0
# 8  545454           Sales Lead     Lucas  19500.0   97500.0
# 9   83000        Product Owner       Mia  20750.0  103750.0

# %%
data1 = {
    "Order_ID": [
        201,202,203,204,205,206,207,208,209,210,
        211,212,213,214,215
    ],
    "Product": [
        "iPhone 15","MacBook Air","iPad Pro","AirPods Pro","Apple Watch",
        "iPhone 14","MacBook Pro","iPad Air","AirPods Max","Apple Watch Ultra",
        "iMac","iPhone 13","Mac Mini","iPad Mini","AirPods 3"
    ],
    "Category": [
        "iPhone","Mac","iPad","Accessories","Wearables",
        "iPhone","Mac","iPad","Accessories","Wearables",
        "Mac","iPhone","Mac","iPad","Accessories"
    ],
    "Price": [
        280000,350000,250000,75000,120000,
        240000,500000,180000,150000,220000,
        400000,200000,180000,140000,60000
    ],
    "Quantity": [
        2,1,1,3,2,
        2,1,2,1,1,
        1,3,2,2,4
    ],
    "Region": [
        "Karachi","Lahore","Islamabad","Karachi","Lahore",
        "Islamabad","Karachi","Lahore","Islamabad","Karachi",
        "Lahore","Islamabad","Karachi","Lahore","Islamabad"
    ],
    "Order_Date": [
        "2024-01-05","2024-01-10","2024-01-15","2024-01-20","2024-01-25",
        "2024-02-01","2024-02-05","2024-02-10","2024-02-15","2024-02-20",
        "2024-03-01","2024-03-05","2024-03-10","2024-03-15","2024-03-20"
    ]
}

# %%
df = pd.DataFrame(data1)
df
# Out:
#     Order_ID            Product     Category   Price  Quantity     Region  \
# 0        201          iPhone 15       iPhone  280000         2    Karachi
# 1        202        MacBook Air          Mac  350000         1     Lahore
# 2        203           iPad Pro         iPad  250000         1  Islamabad
# 3        204        AirPods Pro  Accessories   75000         3    Karachi
# 4        205        Apple Watch    Wearables  120000         2     Lahore
# 5        206          iPhone 14       iPhone  240000         2  Islamabad
# 6        207        MacBook Pro          Mac  500000         1    Karachi
# 7        208           iPad Air         iPad  180000         2     Lahore
# 8        209        AirPods Max  Accessories  150000         1  Islamabad
# 9        210  Apple Watch Ultra    Wearables  220000         1    Karachi
# 10       211               iMac          Mac  400000         1     Lahore
# 11       212          iPhone 13       iPhone  200000         3  Islamabad
# ...

# %%
df.rename(columns = {"Product" : "Type" } , inplace  = True)
df
# Out:
#     Order_ID               Type     Category   Price  Quantity     Region  \
# 0        201          iPhone 15       iPhone  280000         2    Karachi
# 1        202        MacBook Air          Mac  350000         1     Lahore
# 2        203           iPad Pro         iPad  250000         1  Islamabad
# 3        204        AirPods Pro  Accessories   75000         3    Karachi
# 4        205        Apple Watch    Wearables  120000         2     Lahore
# 5        206          iPhone 14       iPhone  240000         2  Islamabad
# 6        207        MacBook Pro          Mac  500000         1    Karachi
# 7        208           iPad Air         iPad  180000         2     Lahore
# 8        209        AirPods Max  Accessories  150000         1  Islamabad
# 9        210  Apple Watch Ultra    Wearables  220000         1    Karachi
# 10       211               iMac          Mac  400000         1     Lahore
# 11       212          iPhone 13       iPhone  200000         3  Islamabad
# ...

# %%
df.loc[(df.Category == "iPhone" ) & (df.Price > 100000) & (df.Region == "Karachi")]
# Out:
#    Order_ID       Type Category   Price  Quantity   Region  Order_Date
# 0       201  iPhone 15   iPhone  280000         2  Karachi  2024-01-05

# %%
df[df["Category"].str.contains("Mac" , "iPad")]
# Out:
#     Order_ID         Type Category   Price  Quantity   Region  Order_Date
# 1        202  MacBook Air      Mac  350000         1   Lahore  2024-01-10
# 6        207  MacBook Pro      Mac  500000         1  Karachi  2024-02-05
# 10       211         iMac      Mac  400000         1   Lahore  2024-03-01
# 12       213     Mac Mini      Mac  180000         2  Karachi  2024-03-10

# %%
df.isnull().sum()
# Out:
# Order_ID      0
# Type          0
# Category      0
# Price         0
# Quantity      0
# Region        0
# Order_Date    0
# dtype: int64

# %%
df["Category"].value_counts()
# Out:
# Category
# Mac            4
# iPhone         3
# iPad           3
# Accessories    3
# Wearables      2
# Name: count, dtype: int64

# %%
df.groupby("Category")["Price"].sum()
# Out:
# Category
# Accessories     285000
# Mac            1430000
# Wearables       340000
# iPad            570000
# iPhone          720000
# Name: Price, dtype: int64

# %%
df.groupby("Category").agg({"Price" : "mean" , "Order_ID" : "count"})
# Out:
#                 Price  Order_ID
# Category
# Accessories   95000.0         3
# Mac          357500.0         4
# Wearables    170000.0         2
# iPad         190000.0         3
# iPhone       240000.0         3

# %%
df = pd.read_csv(r"C:\Users\asifb\OneDrive\Desktop\Python language\Jupyter Notebook\Data sets\countries.csv")
df
# Out:
#         Country  Region  Population  GDP_per_capita
# 0      Pakistan    Asia   240000000            1500
# 1         India    Asia  1400000000            2500
# 2         China    Asia  1410000000           12000
# 3       Germany  Europe    83000000           48000
# 4        France  Europe    67000000           45000
# ..          ...     ...         ...             ...
# 91       Rwanda  Africa    14000000             900
# 92      Burundi  Africa    13000000             300
# 93     Cameroon  Africa    28000000            1600
# 94      Senegal  Africa    18000000            1800
# 95  Ivory Coast  Africa    28000000            2500
#
# [96 rows x 4 columns]

# %%
df.describe()
# Out:
#          Population  GDP_per_capita
# count  9.600000e+01       96.000000
# mean   7.187208e+07    21103.125000
# std    2.048841e+08    24797.230122
# min    3.700000e+05      300.000000
# 25%    6.950000e+06     3500.000000
# 50%    1.900000e+07     9000.000000
# 75%    5.275000e+07    38500.000000
# max    1.410000e+09   120000.000000

# %%
df.rename(columns = {"GDP_per_capita" : "GDP"}, inplace = True)
df
# Out:
#         Country  Region  Population    GDP
# 0      Pakistan    Asia   240000000   1500
# 1         India    Asia  1400000000   2500
# 2         China    Asia  1410000000  12000
# 3       Germany  Europe    83000000  48000
# 4        France  Europe    67000000  45000
# ..          ...     ...         ...    ...
# 91       Rwanda  Africa    14000000    900
# 92      Burundi  Africa    13000000    300
# 93     Cameroon  Africa    28000000   1600
# 94      Senegal  Africa    18000000   1800
# 95  Ivory Coast  Africa    28000000   2500
#
# [96 rows x 4 columns]

# %%
df.set_index("Country", inplace = True)
df
# Out:
#              Region  Population    GDP
# Country
# Pakistan       Asia   240000000   1500
# India          Asia  1400000000   2500
# China          Asia  1410000000  12000
# Germany      Europe    83000000  48000
# France       Europe    67000000  45000
# ...             ...         ...    ...
# Rwanda       Africa    14000000    900
# Burundi      Africa    13000000    300
# Cameroon     Africa    28000000   1600
# Senegal      Africa    18000000   1800
# Ivory Coast  Africa    28000000   2500
#
# [96 rows x 3 columns]

# %%
df.loc["Pakistan"]
# Out:
# Region             Asia
# Population    240000000
# GDP                1500
# Name: Pakistan, dtype: object

# %%
df.reset_index(inplace = True)

# %%
df.set_index(["Region", "Country"] , inplace = True)
df
# Out:
#                     Population    GDP
# Region Country
# Asia   Pakistan      240000000   1500
#        India        1400000000   2500
#        China        1410000000  12000
# Europe Germany        83000000  48000
#        France         67000000  45000
# ...                        ...    ...
# Africa Rwanda         14000000    900
#        Burundi        13000000    300
#        Cameroon       28000000   1600
#        Senegal        18000000   1800
#        Ivory Coast    28000000   2500
#
# [96 rows x 2 columns]

# %%
pd.set_option("display.max_rows" , 96)
df
# Out:
#                                   Population     GDP
# Region        Country
# Asia          Pakistan             240000000    1500
#               India               1400000000    2500
#               China               1410000000   12000
# Europe        Germany               83000000   48000
#               France                67000000   45000
#               UK                    67000000   46000
# North America USA                  331000000   70000
#               Canada                38000000   52000
# South America Brazil               215000000    9000
#               Argentina             45000000   10000
# Africa        Nigeria              223000000    2200
#               South Africa          60000000    7000
# Oceania       Australia             26000000   55000
#               New Zealand            5000000   48000
# Asia          Japan                125000000   42000
#               Bangladesh           170000000    2800
# ...

# %%
df.loc["Asia" , "Pakistan"]
# Out:
# Population    240000000
# GDP                1500
# Name: (Asia, Pakistan), dtype: int64

# %%
df.groupby("Region").agg({"Population" : "sum" })
# Out:
#                Population
# Region
# Africa         1101200000
# Asia           4201300000
# Europe          561420000
# North America   569900000
# Oceania          31000000
# South America   434900000

# %%
df.groupby("Region").agg({"Population" : "min" , "GDP" : "max"})
# Out:
#                Population     GDP
# Region
# Africa            2600000    7000
# Asia              3000000   60000
# Europe             370000  120000
# North America     4400000   70000
# Oceania           5000000   55000
# South America      600000   18000

# %%
df.loc[df.groupby("Region")["GDP"].idxmax()]
# Out:
#                             Population     GDP
# Region        Country
# Africa        South Africa    60000000    7000
# Asia          Qatar            3000000   60000
# Europe        Luxembourg        650000  120000
# North America USA            331000000   70000
# Oceania       Australia       26000000   55000
# South America Uruguay          3500000   18000

# %%
data = {
    "Name": [
        "Liam", "Sophia", "Noah", "Emma", "Oliver", 
        "Ava", "Ethan", "Isabella", "Lucas", "Mia"
    ],
    "Salary": [
        95000, 72000, 105000, 88000, 62000, 
        115000, 54000, 91000, 78000, 83000
    ],
    "Position": [
        "Software Engineer", "Data Scientist", "Project Manager", "UX Designer", "Intern",
        "CTO", "Marketing Associate", "DevOps Engineer", "Sales Lead", "Product Owner"
    ]}

# %%
df  = pd.DataFrame(data)
df
# Out:
#        Name  Salary             Position
# 0      Liam   95000    Software Engineer
# 1    Sophia   72000       Data Scientist
# 2      Noah  105000      Project Manager
# 3      Emma   88000          UX Designer
# 4    Oliver   62000               Intern
# 5       Ava  115000                  CTO
# 6     Ethan   54000  Marketing Associate
# 7  Isabella   91000      DevOps Engineer
# 8     Lucas   78000           Sales Lead
# 9       Mia   83000        Product Owner

# %%
df[["Name" , "Salary"]].head()
# Out:
#      Name  Salary
# 0    Liam   95000
# 1  Sophia   72000
# 2    Noah  105000
# 3    Emma   88000
# 4  Oliver   62000

# %%
df.iloc[2:4 , 0:1]  # first is for rows and after comma is for columns
# Out:
#    Name
# 2  Noah
# 3  Emma

# %%
df[["Name" , "Salary"]].iloc[1:8]
# Out:
#        Name  Salary
# 1    Sophia   72000
# 2      Noah  105000
# 3      Emma   88000
# 4    Oliver   62000
# 5       Ava  115000
# 6     Ethan   54000
# 7  Isabella   91000

# %%
df.loc[len(df)] = ["Ali", 100000 , "AI engineer"]
df
# Out:
#         Name  Salary             Position
# 0       Liam   95000    Software Engineer
# 1     Sophia   72000       Data Scientist
# 2       Noah  105000      Project Manager
# 3       Emma   88000          UX Designer
# 4     Oliver   62000               Intern
# 5        Ava  115000                  CTO
# 6      Ethan   54000  Marketing Associate
# 7   Isabella   91000      DevOps Engineer
# 8      Lucas   78000           Sales Lead
# 9        Mia   83000        Product Owner
# 10       Ali  100000          AI engineer

# %%
df.loc[len(df)-3] = ["Shahzaib", 100000 , "AI engineer"]
df
# Out:
#         Name  Salary             Position
# 0       Liam   95000    Software Engineer
# 1     Sophia   72000       Data Scientist
# 2       Noah  105000      Project Manager
# 3       Emma   88000          UX Designer
# 4     Oliver   62000               Intern
# 5        Ava  115000                  CTO
# 6      Ethan   54000  Marketing Associate
# 7   Isabella   91000      DevOps Engineer
# 8   Shahzaib  100000          AI engineer
# 9        Mia   83000        Product Owner
# 10       Ali  100000          AI engineer

# %%
len(df.Position.unique())
# Out:
# 10

# %%
df[(df.Position == "Product Owner") & (df.Salary > 50000)]
# Out:
#   Name  Salary       Position
# 9  Mia   83000  Product Owner

# %%
df = pd.read_excel(r"C:\Users\asifb\OneDrive\Desktop\Python language\Jupyter Notebook\Data sets\messy_sales_data.xlsx")
df
# Out:
#      Order_ID        Date Customer_Name                 Email Region  \
# 0        1001  2024-01-05      John Doe    john.doe@email.com  North
# 1        1002  2024-01-07    Jane Smith  jane.smith@email.com  South
# 2        1001  2024-01-05      John Doe    john.doe@email.com  North
# 3        1003  2024-01-10           NaN       carol@email.com   East
# 4        1004  2024-01-12    Mike Brown                   NaN   West
# ..        ...         ...           ...                   ...    ...
# 96       1096  2024-02-13      Eve Hall     evehall@email.com   West
# 97       1097  2024-09-25    Hank Jones   hankjones@gmail.com  South
# 98       1098  2024-10-20   Grace Young  graceyoung@yahoo.com   West
# 99       1099  2024-03-18   Alice Young  aliceyoung@gmail.com  South
# 100      1100  2024-12-10     Bob Brown    bobbrown@gmail.com   West
#
#       Product     Category Quantity Unit_Price  Total_Sales  Discount_%  \
# ...

# %%
type(df.Date[0])
# Out:
# str

# %%
df["Date"] = pd.to_datetime(df.Date, format = "mixed" , dayfirst = True)

# %%
type(df["Date"])
# Out:
# pandas.Series

# %%
df["Date"][0:2].dt.month
# Out:
# 0    5
# 1    7
# Name: Date, dtype: int32

# %%
df
# Out:
#      Order_ID       Date Customer_Name                 Email Region   Product  \
# 0        1001 2024-05-01      John Doe    john.doe@email.com  North    Laptop
# 1        1002 2024-07-01    Jane Smith  jane.smith@email.com  South     Mouse
# 2        1001 2024-05-01      John Doe    john.doe@email.com  North    Laptop
# 3        1003 2024-10-01           NaN       carol@email.com   East  Keyboard
# 4        1004 2024-12-01    Mike Brown                   NaN   West   Monitor
# ..        ...        ...           ...                   ...    ...       ...
# 96       1096 2024-02-13      Eve Hall     evehall@email.com   West  Keyboard
# 97       1097 2024-09-25    Hank Jones   hankjones@gmail.com  South     Mouse
# 98       1098 2024-10-20   Grace Young  graceyoung@yahoo.com   West   Monitor
# 99       1099 2024-03-18   Alice Young  aliceyoung@gmail.com  South    Webcam
# 100      1100 2024-10-12     Bob Brown    bobbrown@gmail.com   West   Monitor
#
# ...

# %%
df["Month"] = df["Date"].dt.month

# %%
df.sort_values("Date", inplace = True)

# %%
df
# Out:
#     Order_ID       Date Customer_Name                   Email Region  \
# 24      1024 2024-01-03           NaN           n/a@email.com   East
# 6       1006 2024-01-15     Tom Clark           tom@email.com  South
# 7       1007 2024-01-18     Lisa Hall          lisa@email.com   East
# 95      1095 2024-01-19  Carol Wilson   carolwilson@gmail.com  North
# 8       1008 2024-01-20  James Wilson         james@email.com  north
# ..       ...        ...           ...                     ...    ...
# 92      1092 2024-12-15   Dave Wilson  davewilson@hotmail.com   West
# 43      1043 2024-12-16   Alice Jones  alicejones@hotmail.com   East
# 94      1094 2024-12-18   Hank Wilson  hankwilson@hotmail.com  North
# 63      1063 2024-12-26    Dave Brown     davebrown@yahoo.com   West
# 5       1005        NaT      Sara Lee          sara@email.com  North
#
#        Product     Category Quantity Unit_Price  Total_Sales  Discount_%  \
# ...

# %%
df.drop(labels = "Total_Sales" , axis =1 , inplace = True )
df
# Out:
#     Order_ID       Date Customer_Name                   Email Region  \
# 24      1024 2024-01-03           NaN           n/a@email.com   East
# 6       1006 2024-01-15     Tom Clark           tom@email.com  South
# 7       1007 2024-01-18     Lisa Hall          lisa@email.com   East
# 95      1095 2024-01-19  Carol Wilson   carolwilson@gmail.com  North
# 8       1008 2024-01-20  James Wilson         james@email.com  north
# ..       ...        ...           ...                     ...    ...
# 92      1092 2024-12-15   Dave Wilson  davewilson@hotmail.com   West
# 43      1043 2024-12-16   Alice Jones  alicejones@hotmail.com   East
# 94      1094 2024-12-18   Hank Wilson  hankwilson@hotmail.com  North
# 63      1063 2024-12-26    Dave Brown     davebrown@yahoo.com   West
# 5       1005        NaT      Sara Lee          sara@email.com  North
#
#        Product     Category Quantity Unit_Price  Discount_%      Sales_Rep  \
# ...

# %%
df.dropna(subset= ["Date" , "Customer_Name", "Sales_Rep", "Email" , "Status"] , inplace =  True)

# %%
df["Unit_price1"] = pd.to_numeric(df["Unit_Price"] , errors = "coerce")

# %%
df["Unit_price1"].max()
# Out:
# np.float64(999.99)

# %%
df.drop(labels = "Unit_price" , axis =1 , inplace = True)

# %%
df["Unit_price1"].idxmin()
# Out:
# np.int64(11)

# %%
df["Unit_price1"].idxmin()
# Out:
# np.int64(11)

# %%
df.loc[11]
# Out:
# Order_ID                        1011
# Date             2024-01-27 00:00:00
# Customer_Name            Anna Taylor
# Email                 anna@email.com
# Region                         North
# Product                     Keyboard
# Category                 Accessories
# Quantity                           2
# Discount_%                       0.0
# Sales_Rep              Alice Johnson
# Status                     Completed
# Month                            1.0
# Unit_price1                   -49.99
# Name: 11, dtype: object

# %%
df["Category"].value_counts()
# Out:
# Category
# Electronics    52
# Accessories    42
# electronics     1
# ACCESSORIES     1
# Name: count, dtype: int64

# %%
df.groupby("Category")["Unit_price1"].sum()
# Out:
# Category
# ACCESSORIES       29.99
# Accessories    14431.94
# Electronics    21015.01
# electronics      999.99
# Name: Unit_price1, dtype: float64

# %%
df["Category"] = df["Category"].str.title()

# %%
df.groupby(["Category","Status"])["Unit_price1"].sum()
# Out:
# Category     Status
# Accessories  Cancelled    5324.86
#              Cancled        49.99
#              Completed    5965.18
#              PENDING        29.99
#              Pending      3091.91
# Electronics  Cancelled    8014.70
#              Compelted     299.99
#              Completed    8937.66
#              Pending      3762.66
#              completed     999.99
# Name: Unit_price1, dtype: float64

# %%
df.groupby("Category")[["Unit_price1","Discount_%"]].mean()
# Out:
#              Unit_price1  Discount_%
# Category
# Accessories   344.331667   10.833333
# Electronics   415.377358    8.301887

# %%
data = {
    "Job_Title": [
        "Software Engineer", "Software Engineer", "Software Engineer",
        "Data Analyst", "Data Analyst", "Data Analyst",
        "Data Scientist", "Data Scientist", "Data Scientist",
        "Frontend Developer", "Frontend Developer", "Frontend Developer",
        "DevOps Engineer", "DevOps Engineer", "DevOps Engineer",
        "Accountant", "Accountant", "Accountant",
        "Financial Analyst", "Financial Analyst", "Financial Analyst",
        "Bank Officer", "Bank Officer", "Bank Officer",
        "Marketing Manager", "Marketing Manager", "Marketing Manager",
        "SEO Specialist", "SEO Specialist", "SEO Specialist",
        "Content Writer", "Content Writer", "Content Writer",
        "Doctor (MBBS)", "Doctor (MBBS)", "Doctor (MBBS)",
        "Pharmacist", "Pharmacist", "Pharmacist",
        "Nurse", "Nurse", "Nurse",
        "Civil Engineer", "Civil Engineer", "Civil Engineer",
        "Mechanical Engineer", "Mechanical Engineer", "Mechanical Engineer",
    ],
    "Category": [
        "Tech", "Tech", "Tech",
        "Tech", "Tech", "Tech",
        "Tech", "Tech", "Tech",
        "Tech", "Tech", "Tech",
        "Tech", "Tech", "Tech",
        "Finance", "Finance", "Finance",
        "Finance", "Finance", "Finance",
        "Finance", "Finance", "Finance",
        "Marketing", "Marketing", "Marketing",
        "Marketing", "Marketing", "Marketing",
        "Marketing", "Marketing", "Marketing",
        "Healthcare", "Healthcare", "Healthcare",
        "Healthcare", "Healthcare", "Healthcare",
        "Healthcare", "Healthcare", "Healthcare",
        "Engineering", "Engineering", "Engineering",
        "Engineering", "Engineering", "Engineering",
    ],
    "City": [
        "Karachi", "Lahore", "Islamabad",
        "Karachi", "Lahore", "Islamabad",
        "Karachi", "Lahore", "Islamabad",
        "Karachi", "Lahore", "Islamabad",
        "Karachi", "Lahore", "Islamabad",
        "Karachi", "Lahore", "Islamabad",
        "Karachi", "Lahore", "Islamabad",
        "Karachi", "Lahore", "Rawalpindi",
        "Karachi", "Lahore", "Islamabad",
        "Karachi", "Lahore", "Islamabad",
        "Karachi", "Lahore", "Islamabad",
        "Karachi", "Lahore", "Islamabad",
        "Karachi", "Lahore", "Peshawar",
        "Karachi", "Lahore", "Faisalabad",
        "Karachi", "Lahore", "Islamabad",
        "Karachi", "Lahore", "Islamabad",
    ],
    "Experience": [
        "Junior (0-2 yrs)", "Mid (3-5 yrs)", "Senior (6+ yrs)",
        "Junior (0-2 yrs)", "Mid (3-5 yrs)", "Senior (6+ yrs)",
        "Junior (0-2 yrs)", "Mid (3-5 yrs)", "Senior (6+ yrs)",
        "Junior (0-2 yrs)", "Mid (3-5 yrs)", "Senior (6+ yrs)",
        "Junior (0-2 yrs)", "Mid (3-5 yrs)", "Senior (6+ yrs)",
        "Junior (0-2 yrs)", "Mid (3-5 yrs)", "Senior (6+ yrs)",
        "Junior (0-2 yrs)", "Mid (3-5 yrs)", "Senior (6+ yrs)",
        "Junior (0-2 yrs)", "Mid (3-5 yrs)", "Senior (6+ yrs)",
        "Junior (0-2 yrs)", "Mid (3-5 yrs)", "Senior (6+ yrs)",
        "Junior (0-2 yrs)", "Mid (3-5 yrs)", "Senior (6+ yrs)",
        "Junior (0-2 yrs)", "Mid (3-5 yrs)", "Senior (6+ yrs)",
        "Junior (0-2 yrs)", "Mid (3-5 yrs)", "Senior (6+ yrs)",
        "Junior (0-2 yrs)", "Mid (3-5 yrs)", "Senior (6+ yrs)",
        "Junior (0-2 yrs)", "Mid (3-5 yrs)", "Senior (6+ yrs)",
        "Junior (0-2 yrs)", "Mid (3-5 yrs)", "Senior (6+ yrs)",
        "Junior (0-2 yrs)", "Mid (3-5 yrs)", "Senior (6+ yrs)",
    ],
    "Salary_PKR": [
        85000, 150000, 280000,
        70000, 120000, 220000,
        90000, 160000, 320000,
        75000, 140000, 260000,
        80000, 160000, 300000,
        55000, 90000, 160000,
        65000, 120000, 210000,
        60000, 95000, 170000,
        70000, 110000, 200000,
        50000, 85000, 140000,
        40000, 70000, 120000,
        120000, 220000, 420000,
        65000, 100000, 180000,
        45000, 70000, 120000,
        70000, 130000, 240000,
        65000, 120000, 220000,
    ]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#               Job_Title     Category        City        Experience  Salary_PKR
# 0     Software Engineer         Tech     Karachi  Junior (0-2 yrs)       85000
# 1     Software Engineer         Tech      Lahore     Mid (3-5 yrs)      150000
# 2     Software Engineer         Tech   Islamabad   Senior (6+ yrs)      280000
# 3          Data Analyst         Tech     Karachi  Junior (0-2 yrs)       70000
# 4          Data Analyst         Tech      Lahore     Mid (3-5 yrs)      120000
# 5          Data Analyst         Tech   Islamabad   Senior (6+ yrs)      220000
# 6        Data Scientist         Tech     Karachi  Junior (0-2 yrs)       90000
# 7        Data Scientist         Tech      Lahore     Mid (3-5 yrs)      160000
# 8        Data Scientist         Tech   Islamabad   Senior (6+ yrs)      320000
# 9    Frontend Developer         Tech     Karachi  Junior (0-2 yrs)       75000
# 10   Frontend Developer         Tech      Lahore     Mid (3-5 yrs)      140000
# ...

# %%
df.rename(columns = {"Salary_PKR": "Salary"} , inplace = True)

# %%
df.groupby(["City" , "Job_Title"])["Salary"].mean()
# Out:
# City        Job_Title
# Faisalabad  Nurse                  120000.0
# Islamabad   Accountant             160000.0
#             Civil Engineer         240000.0
#             Content Writer         120000.0
#             Data Analyst           220000.0
#             Data Scientist         320000.0
#             DevOps Engineer        300000.0
#             Doctor (MBBS)          420000.0
#             Financial Analyst      210000.0
#             Frontend Developer     260000.0
#             Marketing Manager      200000.0
#             Mechanical Engineer    220000.0
#             SEO Specialist         140000.0
#             Software Engineer      280000.0
# Karachi     Accountant              55000.0
#             Bank Officer            60000.0
#             Civil Engineer          70000.0
#             Content Writer          40000.0
#             Data Analyst            70000.0
#             Data Scientist          90000.0
#             DevOps Engineer         80000.0
# ...

# %%
Karachi_jobs = df[df["City"] == "Karachi"]

# %%
Karachi_jobs["Salary"].mean()
# Out:
# np.float64(69062.5)

# %%
df.groupby("Job_Title")[["Salary"]].agg(["mean", "min" , "max"]).sort_values(by = ("Salary","mean"))
# Out:
#                             Salary
#                               mean     min     max
# Job_Title
# Content Writer        76666.666667   40000  120000
# Nurse                 78333.333333   45000  120000
# SEO Specialist        91666.666667   50000  140000
# Accountant           101666.666667   55000  160000
# Bank Officer         108333.333333   60000  170000
# Pharmacist           115000.000000   65000  180000
# Marketing Manager    126666.666667   70000  200000
# Financial Analyst    131666.666667   65000  210000
# Mechanical Engineer  135000.000000   65000  220000
# Data Analyst         136666.666667   70000  220000
# Civil Engineer       146666.666667   70000  240000
# Frontend Developer   158333.333333   75000  260000
# Software Engineer    171666.666667   85000  280000
# DevOps Engineer      180000.000000   80000  300000
# Data Scientist       190000.000000   90000  320000
# Doctor (MBBS)        253333.333333  120000  420000
