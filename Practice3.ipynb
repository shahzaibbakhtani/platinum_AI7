# %%
print("Hello world")
# Out:
# Hello world

# %%
import pyttsx3

# %%
print("my date of birth is 30 october 2002")
# Out:
# my date of birth is 30 october 2002

# %%
Name = "shahzaib Assar ali"

# %%
Name
# Out:
# 'shahzaib Assar ali'

# %%
Name2 = "Shahzaib"
Name3 = "Shireen"    # ----> Varriables

# %%
Name3 + " " + Name2
# Out:
# 'Shireen Shahzaib'

# %%
a = 1

# %%
b = 45
c= a+b

# %%
c
# Out:
# 46

# %%
A = "Harry"  # A is string 
B= 2        # B is floating  
C= False     # C is bulleon

# %%
shahzaib = 123

# %%
shahzaib
# Out:
# 123

# %%
A = 5 
B = 6
B += 4 
print(B+A)
# Out:
# 15

# %%
print(not(False))
# Out:
# True

# %%
a = 45
t = type(a)
print(t)
# Out:
# <class 'int'>

# %%
a = "31.2"
b =float(a)
t =type(b)
print(t)
t1 = type(a)
print(t1)
# Out:
# <class 'float'>
# <class 'str'>

# %%
C= 31
float(C)
t = type(C)
print(t)
# Out:
# <class 'int'>

# %%
str(31)
# Out:
# '31'

# %%
float(C)
# Out:
# 31.0

# %%
type(C)
# Out:
# int

# %%
a = int(input("Enter number 1 :"))
b = int(input(" Enter number 2 : "))
print(" A is greater than B is :", a<b)
# Out:
# Enter number 1 : 5
#  Enter number 2 :  7
#  A is greater than B is : True

# %%
a = int(input("Enter number 1 :"))
b= int(input("Enter number 2 : "))
print("The average of these to numbers is :", a+b/2)
# Out:
# Enter number 1 : 55
# Enter number 2 :  5
# The average of these to numbers is : 57.5

# %%
name = "Shahzaib"
Length =  len(name)
print(Length)
# Out:
# 8

# %%
name =  "Shahzaib"
nameshort =  name[0:3]      #  through this we can find the piece of name from first character to third 
print(nameshort)
# Out:
# Sha

# %%
character1 = name[0]
print(character1)
# Out:
# S

# %%
print(name[-4:-1])
print(name[1:4])
# Out:
# zai
# hah

# %%
print(name[0:])
# Out:
# Shahzaib

# %%
name[0:8:2]
# Out:
# 'Sazi'

# %%
print(len(name))
# Out:
# 8

# %%
print(name.endswith("aib"))
# Out:
# True

# %%
print(name.startswith("Shah"))
# Out:
# True

# %%
name2 = "shireen"

# %%
C = name2.capitalize()
print(C)
# Out:
# Shireen

# %%
h = "Shahzaib is a good good boy"
h.replace("good","bad")
# Out:
# 'Shahzaib is a bad bad boy'

# %%
f = "Shahzaib is a good boy and\nhe is working very hard"  # \n --> this adds a line space between two lines 
print(f)
# Out:
# Shahzaib is a good boy and
# he is working very hard

# %%
name = input("Whats is your name ")
print(f"Good Afternoon", name)
# Out:
# Whats is your name  Shahzaib
# Good Afternoon Shahzaib

# %%
Letter =  "Dear name , you are selected ,\non date\nCongratualtios."
print(Letter.replace("name","Asad").replace("date","11/Mar/2026"))
# Out:
# Dear Asad , you are selected ,
# on 11/Mar/2026
# Congratualtios.

# %%
a = 31.2
t =type(a)
print(t)
# Out:
# <class 'float'>

# %%
c = str(a)
t = type(c)
print(t)
# Out:
# <class 'str'>

# %%
c
# Out:
# '31.2'

# %%
a = int(input("Enter number 1 : "))
b = int(input("Enter number 2 : "))
print("Is A is greater than B : " , a>b)
# Out:
# Enter number 1 :  32
# Enter number 2 :  44
# Is A is greater than B :  False

# %%
a = int(input("Enter number 1 : "))
b = int(input("Enter number 2 : "))
print("The average of these numbers is :" , a+b/2)
# Out:
# Enter number 1 :  50
# Enter number 2 :  30
# The average of these numbers is : 65.0

# %%
name = "Shahzaib"
nameshort = name[0:5]
print(nameshort)
t = type(nameshort)
print(t)
l = len(nameshort)
print(l)
# Out:
# Shahz
# <class 'str'>
# 5

# %%
t = "Pakistan is wonderful country with good safety"
t.replace("good","bad")
# Out:
# 'Pakistan is wonderful country with bad safety'

# %%
Line = "Shahzaib is working to learn python"

# %%
print(Line.find("python"))
# Out:
# 29

# %%
print(Line)
# Out:
# Shahzaib is working to learn python

# %%
line = "Pyhton is  one  of the important language"

# %%
print(line.replace("  "," "))
# Out:
# Pyhton is one of the important language

# %%
line                          # strings are immutable cant change once it has been run
# Out:
# 'Pyhton is  one  of the important language'

# %%
note =  "Dear\n\t Asad this python course is helpful \nThanks!"

# %%
print(note)
# Out:
# Dear
# 	 Asad this python course is helpful
# Thanks!

# %% [markdown]
#  # List

# %%
list1 = ["Shahzaib", "Arfa", "Asif", "Asad"]
print(list1)                                              # unlike strings lists[] are mutable
list1[0] = "Shireen"
print(list1)
# Out:
# ['Shahzaib', 'Arfa', 'Asif', 'Asad']
# ['Shireen', 'Arfa', 'Asif', 'Asad']

# %%
print(list1[0:3])
# Out:
# ['Shireen', 'Arfa', 'Asif']

# %%
list1.append("Assar")
print(list1)
# Out:
# ['Shireen', 'Arfa', 'Asif', 'Asad', 'Assar']

# %%
list1.append("Shahzaib")        # one things at a time is added in list
print(list1)
# Out:
# ['Shireen', 'Arfa', 'Asif', 'Asad', 'Assar', 'Shahzaib', 'Shahzaib']

# %%
list2 = [ 1,55,7,89,22,55,6,23,99]
list2.sort()                            # sort --> ascending order 
print(list2)
# Out:
# [1, 6, 7, 22, 23, 55, 55, 89, 99]

# %%
list2.insert(2, 44)
print(list2)
# Out:
# [1, 6, 44, 7, 22, 23, 55, 55, 89, 99]

# %%
list2.pop(3)
# Out:
# 7

# %%
print(list2)
# Out:
# [1, 6, 44, 22, 23, 55, 55, 89, 99]

# %%
list2.remove(55)
print(list2)              # remove --> exclude that value from list
# Out:
# [1, 22, 23, 55, 89, 99]

# %%
a = (1, 2, "Ali", False)
print(type(a))
# Out:
# <class 'tuple'>

# %%
t1 = (1,2,4,5,55,67,2,33)
print(t1.count(55))
# Out:
# 1

# %%
print(len(t1))
print(sum(t1))                     # tuple diffrent methods 
print(max(t1))
print(min(t1))
# Out:
# 8
# 169
# 67
# 1

# %%
t2 = (1,2,3,4,66,44,67)
t3 = ( 3,5 ,67,88)
t4 = t2 + t3
print(t4)
# Out:
# (1, 2, 3, 4, 66, 44, 67, 3, 5, 67, 88)

# %%
sorted_t = tuple(sorted(t4))
print(sorted_t)                     # cant use sort in tuple we can use this
# Out:
# (1, 2, 3, 3, 4, 5, 44, 66, 67, 67, 88)

# %%
fruits = []

# %%
f1 = input("Enter your fruit: ")
fruits.append(f1)
f2 = input("Enter your fruit: ")
fruits.append(f2)
f3 = input("Enter your fruit: ")
fruits.append(f3)
f4 = input("Enter your fruit: ")
fruits.append(f4)
print("Your selected fruits are :", fruits)
# Out:
# Enter your fruit:  apple
# Enter your fruit:  orange
# Enter your fruit:  grapes
# Enter your fruit:  pineapple
# Your selected fruits are : ['orange', 'apple', 'grapes', 'kiwi', 'apple', 'orange', 'grapes', 'pineapple ']

# %%
fruits.remove("apple")
fruits.remove("orange")
fruits.remove("grapes")
fruits.remove("kiwi")
print(fruits)
# Out:
# ['orange', 'grapes', 'pineapple ']

# %%
marks = []

# %%
f1 = input("Enter your marks: ")
marks.append(f1)
f2 = input("Enter your marks: ")
marks.append(f2)
f3 = input("Enter your marks: ")
marks.append(f3)
f4 = input("Enter your marks: ")
marks.append(f4)
marks.sort()
print("Your marks are :", marks)
# Out:
# Enter your marks:  33
# Enter your marks:  56
# Enter your marks:  10
# Enter your marks:  88
# Your marks are : ['10', '22', '33', '33', '56', '77', '88']

# %%
sum1 = [1,77,9,66]
print(sum(sum1))     # map is use to apply new function on each item in list
# Out:
# 153

# %%
def mul (a,b = 2):
    return a * b

# %%
mul(3)
# Out:
# 6

# %%
def mul(a,b):
    t = a  * b
    print(t)

# %%
mul(77,4)
# Out:
# 308

# %%
def convert (d, p):
    p = d * 280
    print("dollar" ,d , "=" , p , "PKR")

# %%
convert(87,10)
# Out:
# dollar 87 = 24360 PKR

# %%
def convert(d):
    p = d * 280
    return p
print(f"100 dollars = {convert(100)} PKR")
# Out:
# 100 dollars = 28000 PKR

# %%
def name(a):
    print("Hello",a)

# %%
name("shahzaib")
# Out:
# Hello shahzaib

# %%
def convert(a, b =0.621):
    c = a *b
    print(a , "KM= " ,c , "Miles")

# %%
convert(10)
# Out:
# 10 KM=  6.21 Miles

# %%
list =  [2,5,6,7]
def a (list) :
    sum = 0
    for i in list:
        sum+=i
    print(sum)

# %%
a(list)
# Out:
# 20

# %%
list1 = [44,55,88,66]

# %%
a(list1)
# Out:
# 253

# %%
lst = [10000,2000,5000,1000]
def a (lst):
    for i in lst:
        if i > 5000:
            print(i)

# %%
a(lst)
# Out:
# 10000

# %%
list1 = [1000000,200000]
a(list1)
# Out:
# 1000000
# 200000

# %%
lst = [100,44,33,180,222]
# sum = 0
def a (lst):
    sum = 0                 # define inside the function
    for i in lst:
        if i > 50:
            sum += i
    print(sum)

# %%
a(lst)
# Out:
# 502

# %%
salary = [10000,20000,3000]
def a (b):
    for i in salary :
        if i > 5000:
            print(i)

# %%
a(salary)
# Out:
# 10000
# 20000

# %%
d = [10,11,33]
def a (b):
    for i in b:     # jo b ki jagha list aahe ghi wo new list
        c = i * 280
        print(c)

# %%
a(d)
# Out:
# 2800
# 3080
# 9240

# %%
z = [11,33,44]
a(z)
# Out:
# 3080
# 9240
# 12320

# %%
def avg_sal (a):
    c= 0
    for i in a:
        c += i/len(a)
    print(c)

# %%
a = [10,20,30]
avg_sal(a)
# Out:
# 20.0
