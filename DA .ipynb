# %%
import my_module

# %%
my_module.Skill_list
# Out:
# ['Pyhton', 'Excel', 'Power BI']

# %%
my_module.skill("Python")
# Out:
# Python is my favourite skill

# %%
import Job

# %%
Job.Upgrade(10000)
# Out:
# 11000.0

# %%
from Job import Upgrade

# %%
Upgrade(20000)
# Out:
# 22000.0

# %%
from Job import bonus

# %%
bonus(200000,100000)
# Out:
# 100000

# %%
help(bonus)
# Out:
# Help on function bonus in module Job:
#
# bonus(total, salary)
#     It calculates the bonus based on total and base salary

# %%
l1 = [100000,200000,330000,430000,200000]

# %%
import statistics

# %%
statistics.mean(l1)
# Out:
# 252000

# %%
statistics.mode(l1)
# Out:
# 200000
