# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\asifb\OneDrive\Desktop\Python language\Jupyter Notebook\Data sets\messy_sales_data.xlsx")
df
# Out:
#      Order_ID        Date Customer_Name                 Email Region  \
# 0        1001  2024-01-05      John Doe    john.doe@email.com  North
# 1        1002  2024-01-07    Jane Smith  jane.smith@email.com  South
# 2        1001  2024-01-05      John Doe    john.doe@email.com  North
# 3        1003  2024-01-10           NaN       carol@email.com   East
# 4        1004  2024-01-12    Mike Brown                   NaN   West
# ..        ...         ...           ...                   ...    ...
# 96       1096  2024-02-13      Eve Hall     evehall@email.com   West
# 97       1097  2024-09-25    Hank Jones   hankjones@gmail.com  South
# 98       1098  2024-10-20   Grace Young  graceyoung@yahoo.com   West
# 99       1099  2024-03-18   Alice Young  aliceyoung@gmail.com  South
# 100      1100  2024-12-10     Bob Brown    bobbrown@gmail.com   West
#
#       Product     Category Quantity Unit_Price  Total_Sales  Discount_%  \
# ...

# %%
pd.set_option("display.max_rows" , 101)
df
# Out:
#      Order_ID           Date    Customer_Name                   Email Region  \
# 0        1001     2024-01-05         John Doe      john.doe@email.com  North
# 1        1002     2024-01-07       Jane Smith    jane.smith@email.com  South
# 2        1001     2024-01-05         John Doe      john.doe@email.com  North
# 3        1003     2024-01-10              NaN         carol@email.com   East
# 4        1004     2024-01-12       Mike Brown                     NaN   West
# 5        1005            NaN         Sara Lee          sara@email.com  North
# 6        1006     2024-01-15        Tom Clark           tom@email.com  South
# 7        1007     2024-01-18        Lisa Hall          lisa@email.com   East
# 8        1008     2024-01-20     James Wilson         james@email.com  north
# 9        1009     2024-01-22       Emma Davis          emma@email.com  SOUTH
# 10       1010     2024-01-25     Chris Martin         chris@email.com   West
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#      Order_ID           Date    Customer_Name                   Email Region  \
# 0        1001     2024-01-05         John Doe      john.doe@email.com  North
# 1        1002     2024-01-07       Jane Smith    jane.smith@email.com  South
# 3        1003     2024-01-10              NaN         carol@email.com   East
# 4        1004     2024-01-12       Mike Brown                     NaN   West
# 5        1005            NaN         Sara Lee          sara@email.com  North
# 6        1006     2024-01-15        Tom Clark           tom@email.com  South
# 7        1007     2024-01-18        Lisa Hall          lisa@email.com   East
# 8        1008     2024-01-20     James Wilson         james@email.com  north
# 9        1009     2024-01-22       Emma Davis          emma@email.com  SOUTH
# 10       1010     2024-01-25     Chris Martin         chris@email.com   West
# 11       1011     2024-01-27      Anna Taylor          anna@email.com  North
# ...

# %%
df.drop(columns = "Total_Sales" , inplace  = True)

# %%
df
# Out:
#      Order_ID           Date    Customer_Name                   Email Region  \
# 0        1001     2024-01-05         John Doe      john.doe@email.com  North
# 1        1002     2024-01-07       Jane Smith    jane.smith@email.com  South
# 3        1003     2024-01-10              NaN         carol@email.com   East
# 4        1004     2024-01-12       Mike Brown                     NaN   West
# 5        1005            NaN         Sara Lee          sara@email.com  North
# 6        1006     2024-01-15        Tom Clark           tom@email.com  South
# 7        1007     2024-01-18        Lisa Hall          lisa@email.com   East
# 8        1008     2024-01-20     James Wilson         james@email.com  north
# 9        1009     2024-01-22       Emma Davis          emma@email.com  SOUTH
# 10       1010     2024-01-25     Chris Martin         chris@email.com   West
# 11       1011     2024-01-27      Anna Taylor          anna@email.com  North
# ...

# %%
pd.reset_option("display.max_rows")

# %%
df
# Out:
#      Order_ID        Date Customer_Name                 Email Region  \
# 0        1001  2024-01-05      John Doe    john.doe@email.com  North
# 1        1002  2024-01-07    Jane Smith  jane.smith@email.com  South
# 3        1003  2024-01-10           NaN       carol@email.com   East
# 4        1004  2024-01-12    Mike Brown                   NaN   West
# 5        1005         NaN      Sara Lee        sara@email.com  North
# ..        ...         ...           ...                   ...    ...
# 96       1096  2024-02-13      Eve Hall     evehall@email.com   West
# 97       1097  2024-09-25    Hank Jones   hankjones@gmail.com  South
# 98       1098  2024-10-20   Grace Young  graceyoung@yahoo.com   West
# 99       1099  2024-03-18   Alice Young  aliceyoung@gmail.com  South
# 100      1100  2024-12-10     Bob Brown    bobbrown@gmail.com   West
#
#       Product     Category Quantity Unit_Price  Discount_%      Sales_Rep  \
# ...

# %%
df["Customer_Name"].str.lstrip("NaN")
# Out:
# 0         John Doe
# 1       Jane Smith
# 3              NaN
# 4       Mike Brown
# 5         Sara Lee
#           ...
# 96        Eve Hall
# 97      Hank Jones
# 98     Grace Young
# 99     Alice Young
# 100      Bob Brown
# Name: Customer_Name, Length: 100, dtype: str

# %%
df["Date"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df["Date"] = pd.to_datetime(df["Date"], format = "mixed"  , errors = "coerce")
df["Date"].dtype
# Out:
# dtype('<M8[us]')

# %%
df.describe()
# Out:
#           Order_ID                 Date  Total_Sales  Discount_%
# count   101.000000                  100          0.0   99.000000
# mean   1050.009901  2024-05-23 14:09:36          NaN    9.393939
# min    1001.000000  2024-01-04 00:00:00          NaN    0.000000
# 25%    1025.000000  2024-02-13 00:00:00          NaN    0.000000
# 50%    1050.000000  2024-05-07 00:00:00          NaN    5.000000
# 75%    1075.000000  2024-08-14 06:00:00          NaN   15.000000
# max    1100.000000  2024-12-26 00:00:00          NaN  150.000000
# std      29.283270                  NaN          NaN   16.008173

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 100 entries, 0 to 100
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       100 non-null    int64
#  1   Date           99 non-null     datetime64[us]
#  2   Customer_Name  98 non-null     str
#  3   Email          99 non-null     str
#  4   Region         100 non-null    str
#  5   Product        99 non-null     str
#  6   Category       100 non-null    str
#  7   Quantity       100 non-null    object
#  8   Unit_Price     100 non-null    object
#  9   Total_Sales    0 non-null      float64
#  10  Discount_%     98 non-null     float64
#  11  Sales_Rep      99 non-null     str
#  12  Status         99 non-null     str
# dtypes: datetime64[us](1), float64(2), int64(1), object(2), str(7)
# memory usage: 10.9+ KB

# %% [markdown]
# # Data cleaning

# %%
df = pd.read_excel(r"C:\Users\asifb\OneDrive\Desktop\Python language\Jupyter Notebook\Data sets\Data_Cleaning_Simple.xlsx")

# %%
round(df.describe(),2)
# Out:
#        Customer_ID     Age     Salary  Purchases
# count        50.00   49.00      47.00      50.00
# mean        125.50   56.55   71670.66      15.88
# std          14.58  137.97   28426.20       9.63
# min         101.00   -5.00   30074.00       2.00
# 25%         113.25   27.00   50000.00       7.25
# 50%         125.50   37.00   62591.00      14.00
# 75%         137.75   47.00   96272.00      25.00
# max         150.00  999.00  119733.00      30.00

# %%
df.isnull().sum()/len(df)*100
# Out:
# Customer_ID       0.0
# Customer_Name    10.0
# Age               2.0
# Salary            6.0
# Gender            0.0
# Date_Joined       0.0
# City              0.0
# Purchases         0.0
# dtype: float64

# %%
mean = df.Salary.mean()
print(mean)
# Out:
# 71670.65957446808

# %%
df.loc[(df.Gender == "Female") & (df.Salary >= mean)].count()
# Out:
# Customer_ID      8
# Customer_Name    6
# Age              8
# Salary           8
# Gender           8
# Date_Joined      8
# City             8
# Purchases        8
# dtype: int64

# %%
df[df.duplicated()].shape
# Out:
# (0, 8)

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Customer_Name', 'Age', 'Salary', 'Gender',
#        'Date_Joined', 'City', 'Purchases'],
#       dtype='str')

# %%
df["Customer_ID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df["Customer_ID"] == 102]
# Out:
#    Customer_ID Customer_Name   Age    Salary  Gender Date_Joined     City  \
# 1          102  Fatima Malik  27.0  107397.0  Female  2019-03-07  Karachi
#
#    Purchases
# 1          3

# %%
for col in df.columns:         # goes through each column one by one 
    if df[col].nunique() < 20:  # if the column has less than 15 unique values ( we want cities and gender as salary, name, ID these all are unique)
        print(df[col].value_counts())  # count these values
        print("-"*30)
# Out:
# Gender
# Female    24
# Male      23
# male       1
# F          1
# M          1
# Name: count, dtype: int64
# ------------------------------
# City
# Karachi      9
# Islamabad    7
# Lahore       6
# Peshawar     5
# LAhore       3
# Quetta       3
# Islamabdd    2
# Lhore        2
# Peshawer     2
# Quettaa      2
# Karachii     2
# Lahor        2
# Lahorre      1
# QUetta       1
# Peshawr      1
# Islambad     1
# Peshwar      1
# Name: count, dtype: int64
# ------------------------------

# %%
print(df["City"].nunique())   # how many unique city names 
df["City"].value_counts()
# Out:
# 17
# City
# Karachi      9
# Islamabad    7
# Lahore       6
# Peshawar     5
# LAhore       3
# Quetta       3
# Islamabdd    2
# Lhore        2
# Peshawer     2
# Quettaa      2
# Karachii     2
# Lahor        2
# Lahorre      1
# QUetta       1
# Peshawr      1
# Islambad     1
# Peshwar      1
# Name: count, dtype: int64

# %% [markdown]
# ### first step handling missing values

# %%
df.isnull().sum()          # sum of null percolumns 
# df.isnull().count()      # count all values in the column (isnull --> gives true and false table)
# Out:
# Customer_ID      0
# Customer_Name    5
# Age              1
# Salary           3
# Gender           0
# Date_Joined      0
# City             0
# Purchases        0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#     Customer_ID  Customer_Name   Age    Salary  Gender Date_Joined       City  \
# 4           105  ..Zara Sheikh   NaN   50926.0  Female  2020-11-27  Islamabad
# 5           106     Sana Javed  43.0       NaN    Male  2021-02-17    Karachi
# 9           110  Kamran Sheikh  36.0       NaN  Female  2020-07-23   Peshawar
# 12          113            NaN  36.0  119733.0  Female  2023-09-23    Karachi
# 34          135     Bilal Raza  25.0       NaN    Male  2019-05-05   Peshawar
# 36          137            NaN  49.0   54050.0  Female  2021-08-05     Lahore
# 38          139            NaN  53.0   93092.0    Male  2023-11-06    Peshwar
# 47          148            NaN  26.0   31220.0  Female  2022-06-26     Quetta
# 48          149            NaN  35.0   96307.0  Female  2019-09-29  Islamabad
#
#     Purchases
# 4           5
# 5          12
# 9          21
# 12          8
# 34         24
# 36         28
# 38         29
# 47          4
# 48         29

# %%
df.dropna(subset = ["Customer_Name"] , inplace = True)

# %%
df.shape
# Out:
# (45, 8)

# %%
df.isnull().sum()
# Out:
# Customer_ID      0
# Customer_Name    0
# Age              1
# Salary           3
# Gender           0
# Date_Joined      0
# City             0
# Purchases        0
# dtype: int64

# %%
df["Age"].unique()
# Out:
# array([999.,  27.,  36.,  48.,  nan,  43.,  38.,  40.,  24.,  45.,  26.,
#         42.,  25.,  30.,  49.,  22.,  -5.,  54.,  55.,  37.,  52.,  28.,
#         46.,  53.,  47.])

# %%
df["Age"].dtype
# Out:
# dtype('float64')
