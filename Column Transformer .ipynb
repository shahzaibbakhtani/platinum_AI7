# %%
import pandas as pd 
import numpy as np

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder 
from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.read_excel(r"C:\Users\asifb\OneDrive\Desktop\Python languageNotebook\Kaggle\Wine + covid.xlsx", sheet_name = 1, header = 1)\Jupyter

# %%
df.sample(5)
# Out:
#     age  gender  fever   cough       city has_covid
# 47   18  Female  104.0    Mild  Bangalore        No
# 7    20  Female    NaN  Strong     Mumbai       Yes
# 11   65  Female   98.0    Mild     Mumbai       Yes
# 99   10  Female   98.0  Strong    Kolkata       Yes
# 2    42    Male  101.0    Mild      Delhi        No

# %%
df["city"].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(df.iloc[:,0:5],df.iloc[:,-1], test_size = 0.3 , random_state = 42)

# %%
OHE = OneHotEncoder(drop = "first", sparse_output = False)
X_trained = OHE.fit_transform(X_train[["gender", "city"])
X_tested = OHE.fit_transform(X_test[["gender", "city"]])

# %%
from sklearn.compose import ColumnTransformer

# %%
transformer = ColumnTransformer(transformers = [
("first", SimpleImputer(), ["fever"]),
("Second", OrdinalEncoder(categories = [["Mild","Strong"]]), ["cough"]),
("Third" , OneHotEncoder(drop= "first" , sparse_output = False) , ["gender" ,"city"])
],    
remainder = "passthrough")

# %%
transformer.fit_transform(X_train).shape
# Out:
# (70, 7)

# %%
transformer.transform(X_test).shape
# Out:
# (30, 7)
