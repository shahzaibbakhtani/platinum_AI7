# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("Shahzaib first day of learning python")
# Out:
# Shahzaib first day of learning python

# %%
print("Hi world I am coming")
# Out:
# Hi world I am coming

# %%
import pyjokes

# %%
joke = pyjokes.get_joke()   
print(joke)
# Out:
# How come there is no obfuscated Perl contest? Because everyone would win.

# %%
joke=pyjokes.get_joke()
print(joke)
# Out:
# How do you generate a random string? Put a first year Computer Science student in Vim and ask them to save and exit.

# %%
# print ("We are just playing")
joke=pyjokes.get_joke()
print(joke)
# Out:
# I have a dream: 1073741824 bytes free.

# %%
print("HAHAHAHA")
# Out:
# HAHAHAHA

# %%
A = 5
B = 6
B += 10
print(A+B)
# Out:
# 21

# %%
C =  31
float(C)
type(C)
# Out:
# int

# %%
x = 5
y = float(x)
print(y)  # 3.0
# Out:
# 5.0

# %%
B = 10
A = float(B)
type(A)
print(A)
# Out:
# 10.0

# %%
A = int(input("enter number:"))
B = int(input("enter number:"))
print("A is greater than b:", A>B)
# Out:
# enter number: 10
# enter number: 20
# A is greater than b: False

# %%
name =  "Shahzaib"
print(len(name))
short = name[0:3]
print(short)
# Out:
# 8
# Sha

# %%
name = "shahzaiB"
C = name.capitalize()
print(C)
# Out:
# Shahzaib

# %%
t = "Shahzaib love IOBM"
t.replace("love", "hate")
# Out:
# 'Shahzaib hate IOBM'

# %%
a = int(input("Enter your age:"))
if (a>18):
    print("you are good to go")
elif a==0:
    print("you are entering zero")
else:
    print("you are below age ")
# Out:
# Enter your age: 10
# you are below age

# %%
marks = int(input("Enter your marks:"))
age = int(input("enter your age:"))

if marks > 75:
    print("A grade")
elif marks > 60 :
    print("B Grade")
elif marks > 50 :
    print("C Grade")

else :
    print("F grade")

if age > 22: 
    print("High school")
else:
    print("Primary school")
# Out:
# Enter your marks: 56
# enter your age: 19
# C Grade
# Primary school

# %%
a =  int(input("Enter number A:"))
b = int(input("Enter number B:"))
c =int(input("Enter number C:"))

if a>b and a>c:
    print("A is the greatest number")

if b>a and b>c :
    print("B is the greatest number")
if c>a and c>b:
    print("C is the greatest number")
# Out:
# Enter number A: 10
# Enter number B: 20
# Enter number C: 7
# B is the greatest number

# %%
C1 = "big sale"
C2 = "free"
C3= "off"

comment = input("Enter your comment:")

if C1 in comment or C2 in comment or C3 in comment:
    print("This is scam")

else :
    print("You are safe")
# Out:
# Enter your comment: come with us and use everthing in free
# This is scam

# %% [markdown]
# ### Dictionary and lists

# %%
D = {"Sahran" : 88 , "Raju" : 77 , "Anas" : 76}

# %%
print(D.values())
print(D.keys())
print(D.items())
print(type(D))
# Out:
# dict_values([88, 77, 76])
# dict_keys(['Sahran', 'Raju', 'Anas'])
# dict_items([('Sahran', 88), ('Raju', 77), ('Anas', 76)])
# <class 'dict'>

# %%
D.update({"Asad":88})

# %%
print(D.keys())
# Out:
# dict_keys(['Sahran', 'Raju', 'Anas', 'Asad'])

# %%
add = D.setdefault("Shahzaib" , 77)
print(D.keys())
# Out:
# dict_keys(['Sahran', 'Raju', 'Anas', 'Asad', 'Shahzaib'])

# %%
set1 = {1,3,6,7}
set2 = {1,4,5,8}
print(set1)
print(set2)
print(set1.union(set2))
print(set1.intersection(set2))
# Out:
# {1, 3, 6, 7}
# {8, 1, 4, 5}
# {1, 3, 4, 5, 6, 7, 8}
# {1}

# %%
from PyDictionary import PyDictionary

dictionary = PyDictionary()

word = input("Enter a word: ")
meaning = dictionary.meaning(word)

if meaning:
    for part_of_speech, definitions in meaning.items():
        print(f"\n{part_of_speech}:")
        for d in definitions:
            print(f"  - {d}")
else:
    print("Word not found.")
# Out:
# Enter a word:  python
# Word not found.

# %%
words = {"Happy" : "Sad" , "Big" : "small" , "long" : "short", "rich" : "poor"}
word = input("Enter the word to get antonym:")
print(words[word])
